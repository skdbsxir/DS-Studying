# %% [markdown]
# ## Todo List
#
# <br>
#
# 1. 간단한 회귀분석 ($\vee$)
# 2. PCA **$\Leftarrow$ 이거 해볼 차례.**
# 3. Time Series로 접근해서 시각화.

# %%
import numpy as np
import pandas as pd
import warnings, matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# 한글폰트 설정
font_location = 'C:/Windows/Fonts/HYCYSM.TTF'
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family=font_name)

# %%
# 데이터셋을 2개 불러오자.
refined_df = pd.read_csv('UseData/fixed_suicide_4(variable del).csv', index_col=0)
normal_df = pd.read_csv('UseData/fixed_suicide_3.csv', index_col=0)

# %%
refined_df
# Out:
#                 country  year     sex          age  suicides_no  population  \
# 0               Germany  1990    male    75+ years         1516     1717700
# 1               Germany  1990    male  55-74 years         2406     6593100
# 2               Germany  1990    male  35-54 years         3302    11127100
# 3               Germany  1990  female    75+ years         1174     3978800
# 4               Germany  1990    male  25-34 years         1488     6721200
# ...                 ...   ...     ...          ...          ...         ...
# 1051  Republic of Korea  2015  female  35-54 years         1372     8337331
# 1052  Republic of Korea  2015    male  15-24 years          421     3580725
# 1053  Republic of Korea  2015  female  15-24 years          256     3211732
# 1054  Republic of Korea  2015    male   5-14 years           17     2523952
# 1055  Republic of Korea  2015  female   5-14 years           14     2347429
#
#       HDI_for_year   gdp_for_year_($)  gdp_per_capita_($)       generation
# 0            0.801  1,764,967,948,917               23546  G.I. Generation
# 1            0.801  1,764,967,948,917               23546  G.I. Generation
# 2            0.801  1,764,967,948,917               23546           Silent
# 3            0.801  1,764,967,948,917               23546  G.I. Generation
# 4            0.801  1,764,967,948,917               23546          Boomers
# ...            ...                ...                 ...              ...
# 1051         0.907  1,382,764,027,114               28410     Generation X
# 1052         0.907  1,382,764,027,114               28410       Millenials
# 1053         0.907  1,382,764,027,114               28410       Millenials
# 1054         0.907  1,382,764,027,114               28410     Generation Z
# 1055         0.907  1,382,764,027,114               28410     Generation Z
#
# [1056 rows x 10 columns]

# %%
normal_df
# Out:
#                 country  year     sex          age  suicides_no  population  \
# 0               Germany  1990    male    75+ years         1516     1717700
# 1               Germany  1990    male  55-74 years         2406     6593100
# 2               Germany  1990    male  35-54 years         3302    11127100
# 3               Germany  1990  female    75+ years         1174     3978800
# 4               Germany  1990    male  25-34 years         1488     6721200
# ...                 ...   ...     ...          ...          ...         ...
# 1051  Republic of Korea  2015  female  35-54 years         1372     8337331
# 1052  Republic of Korea  2015    male  15-24 years          421     3580725
# 1053  Republic of Korea  2015  female  15-24 years          256     3211732
# 1054  Republic of Korea  2015    male   5-14 years           17     2523952
# 1055  Republic of Korea  2015  female   5-14 years           14     2347429
#
#       suicides/100k pop           country-year  HDI_for_year  \
# 0                 88.26            Germany1990         0.801
# 1                 36.49            Germany1990         0.801
# 2                 29.68            Germany1990         0.801
# 3                 29.51            Germany1990         0.801
# 4                 22.14            Germany1990         0.801
# ...                 ...                    ...           ...
# 1051              16.46  Republic of Korea2015         0.907
# 1052              11.76  Republic of Korea2015         0.907
# 1053               7.97  Republic of Korea2015         0.907
# 1054               0.67  Republic of Korea2015         0.907
# 1055               0.60  Republic of Korea2015         0.907
#
#        gdp_for_year_($)  gdp_per_capita_($)       generation
# 0     1,764,967,948,917               23546  G.I. Generation
# 1     1,764,967,948,917               23546  G.I. Generation
# 2     1,764,967,948,917               23546           Silent
# 3     1,764,967,948,917               23546  G.I. Generation
# 4     1,764,967,948,917               23546          Boomers
# ...                 ...                 ...              ...
# 1051  1,382,764,027,114               28410     Generation X
# 1052  1,382,764,027,114               28410       Millenials
# 1053  1,382,764,027,114               28410       Millenials
# 1054  1,382,764,027,114               28410     Generation Z
# 1055  1,382,764,027,114               28410     Generation Z
#
# [1056 rows x 12 columns]

# %% [markdown]
#     도대체 이 Unnamed: 0은 왜 붙여저 나오는거지
#     index_col=0 지정해서 불러오면 없어진다.

# %%
# str형 float로 바꿔두자.
normal_df['gdp_for_year_($)'] = normal_df['gdp_for_year_($)'].str.replace(',', '')
normal_df['gdp_for_year_($)'] = normal_df['gdp_for_year_($)'].astype('float')

# %%
normal_df.describe()
# Out:
#               year  suicides_no    population  suicides/100k pop  \
# count  1056.000000  1056.000000  1.056000e+03        1056.000000
# mean   2000.738636  1287.778409  6.686407e+06          21.051487
# std       8.622898  1601.653045  4.374955e+06          24.572844
# min    1985.000000     5.000000  1.548000e+05           0.120000
# 25%    1993.750000   231.500000  3.812073e+06           6.330000
# 50%    2001.000000   785.000000  5.099605e+06          13.675000
# 75%    2008.000000  1690.250000  8.748652e+06          27.090000
# max    2015.000000  8948.000000  1.836200e+07         185.370000
#
#        HDI_for_year  gdp_for_year_($)  gdp_per_capita_($)
# count   1056.000000      1.056000e+03         1056.000000
# mean       0.849859      2.576022e+12        28425.375000
# std        0.057187      1.728380e+12        13090.229507
# min        0.707000      1.002731e+11         2731.000000
# 25%        0.814000      9.771480e+11        18849.000000
# 50%        0.858500      2.373445e+12        28415.000000
# 75%        0.892750      4.053161e+12        38476.000000
# max        0.938000      6.203213e+12        51379.000000

# %%
# normal_df 에서 수치형만 빼오자.
features = ['population', 'suicides/100k pop', 'HDI_for_year', 'gdp_for_year_($)',
            'gdp_per_capita_($)']
X = normal_df.loc[:, features].values
Y = normal_df.loc[:, ['suicides_no']].values

print(X)
print(Y)
# Out:
# [[1.71770000e+06 8.82600000e+01 8.01000000e-01 1.76496795e+12
#   2.35460000e+04]
#  [6.59310000e+06 3.64900000e+01 8.01000000e-01 1.76496795e+12
#   2.35460000e+04]
#  [1.11271000e+07 2.96800000e+01 8.01000000e-01 1.76496795e+12
#   2.35460000e+04]
#  ...
#  [3.21173200e+06 7.97000000e+00 9.07000000e-01 1.38276403e+12
#   2.84100000e+04]
#  [2.52395200e+06 6.70000000e-01 9.07000000e-01 1.38276403e+12
#   2.84100000e+04]
#  [2.34742900e+06 6.00000000e-01 9.07000000e-01 1.38276403e+12
#   2.84100000e+04]]
# [[1516]
#  [2406]
#  [3302]
#  ...
#  [ 256]
#  [  17]
#  [  14]]

# %%
# feature들 정규화 하자.
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform(X)
X
# Out:
# array([[-1.13625415e+00,  2.73636860e+00, -8.54769451e-01,
#         -4.69479297e-01, -3.72926002e-01],
#        [-2.13375519e-02,  6.28573090e-01, -8.54769451e-01,
#         -4.69479297e-01, -3.72926002e-01],
#        [ 1.01550698e+00,  3.51306577e-01, -8.54769451e-01,
#         -4.69479297e-01, -3.72926002e-01],
#        ...,
#        [-7.94595807e-01, -5.32607668e-01,  9.99663600e-01,
#         -6.90718319e-01, -1.17509666e-03],
#        [-9.51878766e-01, -8.29824342e-01,  9.99663600e-01,
#         -6.90718319e-01, -1.17509666e-03],
#        [-9.92246412e-01, -8.32674364e-01,  9.99663600e-01,
#         -6.90718319e-01, -1.17509666e-03]])

# %%
# 그러고보면 정규화 하고난 후 상관관계는 어케되지 
heatMap = sns.heatmap(data=X.corr(), annot=True, fmt='.3f', cmap='Blues')
heatMap.set_xticklabels(heatMap.get_xticklabels(), rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-22466b2561d8> in <module>
#       1 # 그러고보면 정규화 하고난 후 상관관계는 어케되지
# ----> 2 heatMap = sns.heatmap(data=X.corr(), annot=True, fmt='.3f', cmap='Blues')
#       3 heatMap.set_xticklabels(heatMap.get_xticklabels(), rotation=45)
#       4 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'corr'

# %% [markdown]
#     아 ㅋㅋ; 댕청
#     values만 뽑아왔으니 ndarray ㅋㅋ

# %%
# 설명가능한 분산량 확인
from sklearn.decomposition import PCA

pca = PCA(random_state=1116)
X_pca = pca.fit_transform(X)

# %%
explainable_var = pd.Series(np.cumsum(pca.explained_variance_ratio_))
explainable_var
# Out:
# 0    0.556991
# 1    0.771933
# 2    0.927006
# 3    0.994678
# 4    1.000000
# dtype: float64

# %%
# 스크리 도표도 한번 그려보자.
percent_variance = np.round(pca.explained_variance_ratio_ * 100, decimals=2)
columns = []

for i in range(len(percent_variance)):
    columns.append(f'PC{i+1}')

ax = plt.bar(x=range(len(percent_variance)), height=percent_variance, tick_label=columns)
plt.rcParams['figure.figsize'] = (20, 15)
plt.xlabel('주성분 갯수')
plt.ylabel('분산 설명량')
plt.title('PCA Scree Plot')
plt.show()

# %% [markdown]
# - 5개의 연속형 속성 $\rightarrow$ 3개의 주성분
#     - 2 차원 낮아짐.
#     - 3개의 주성분으로 데이터를 설명할수 있다? 로 봐야하나?

# %% [markdown]
# https://plotly.com/python/pca-visualization/
#
# <br>
#
# 괜찮은 방법 하나 찾은 것 같다.

# %%
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-86e89bd44552> in <module>
# ----> 1 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.1.0-py2.py3-none-any.whl (20.6 MB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in c:\users\skdbs\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.1.0 tenacity-8.0.1
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\skdbs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\skdbs\anaconda3\lib\site-packages)

# %% [markdown]
#     예시 코드 보고 같이 따라서 쳐보자.

# %%
import plotly.express as px

# %%
components = pca.fit_transform(X)

# %%
labels = {
    str(i) : f"PC{i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    labels=labels,
    dimensions=range(5)
)
fig.update_traces(diagonal_visible=False)
fig.show()
# label이 연속형이라 뭘 어찌 할수가 없는건가?
# Out:
# <div>                            <div id="b29da40c-7565-46b1-b0d0-0a5ef55e00aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b29da40c-7565-46b1-b0d0-0a5ef55e00aa")) {                    Plotly.newPlot(                        "b29da40c-7565-46b1-b0d0-0a5ef55e00aa",                        [{"diagonal":{"visible":false},"dimensions":[{"axis":{"matches":true},"label":"PC1 (55.7%)","values":[1.380190101221304,0.9067183714818188,0.5197779200572539,1.115743912018139,0.8775040970649568,0.7188496957994784,0.9638670667542769,0.5270536355129409,0.8905665775312877,0.9739621895980993,1.0523074735042026,1.0704900294235287,1.2215577149935668,0.6807761647635203,0.31266300903260497,0.9176553671719145,0.6563074424369145,0.49952639580713265,0.775701253845763,0.3203041066282671,0.672352529719857,0.7846952493843952,0.8413501962631952,0.8593533179007276,0.9182086758385001,0.38433790180551775,0.6581365407194458,0.03587433334353584,0.3727958502712418,0.20988640547789222,0.5199049443814717,0.04687299651988327,0.39201539272891217,0.5315645035771942,0.5653655533884036,0.5841523740251207,0.8979726007881271,0.33345047234500397,0.005646341884746798,0.6382401809844426,0.3354501260751462,0.16244517562592217,0.5097429164202769,0.019406339628134324,0.3598324252944033,0.5227955341828464,0.5351890323367736,0.5539710418684415,0.7283556379057371,0.13916144987663973,-0.1597514135363445,0.4740215436703901,0.16675987012372548,0.36013805013786426,-0.025447425955212818,-0.14921871451496072,0.18917315776231067,0.3696472228405618,0.3618221478135759,0.3811860564450033,0.3502553742411942,-0.26449552697083195,-0.5401289711959284,0.09128661359610517,-0.21110121465445683,-0.00969652206739485,-0.4178902837080221,-0.5301665856406516,-0.18797047363391792,-0.0008037899991789883,-0.022184175163061953,-0.0027965733598761494,0.3878194500663601,-0.23558685378610078,-0.49604700372671223,0.12986920739280455,-0.1512235331580615,-0.3732830177531838,0.04691749250669008,-0.48370669657540516,-0.1287317681698827,0.05520513141484571,0.02747860497473541,0.04724689626169285,0.5929326226585516,-0.03300466833315645,-0.28995523329320083,0.3367229926632863,0.0781360378074072,0.2662049216568316,-0.16054232641882493,-0.27999395992581405,0.10017492160864866,0.27239759411922504,0.24444398610157753,0.2648773407486806,0.4908509089033652,-0.13914847763392066,-0.40261538108837025,0.004327085640196049,0.23111179084491315,0.16983800913906189,-0.25705578856900413,-0.39179243048366275,0.021848803689849643,0.17648155377884867,0.15249979597957283,0.1720052277721237,0.4533879592268774,-0.17778504262769868,-0.4492270896491747,0.20033126768994086,0.001827654085878684,0.14082433531184776,-0.28424617200528707,-0.43446204204876293,0.016660806991382893,0.14671595341394347,0.1295664422877096,0.1491560821495523,0.6060887852180223,-0.021761858506887083,-0.3148701976777882,0.3502754369522188,0.1824784313700079,0.29466727403723764,-0.12067485177289165,-0.300044513494108,0.19465552156087199,0.3002436421562328,0.2918212785375215,0.3109118666948941,0.5352092416536985,-0.08607341249803423,-0.4052078426040162,0.28156376340839745,0.14152029814211783,0.2264279376552065,-0.17703493001845616,-0.3896701167049508,0.1497386688566595,0.23073671626327547,0.2329509938038802,0.2515948145500624,0.3671537068201216,-0.24895899298090965,-0.58691555648507,0.11644055875583775,1.8597634701071457e-05,0.06106675236151506,-0.3337164590404968,-0.5706491415065703,0.006698210451877906,0.0655846298593865,0.07694627113856975,0.09578553426767177,-0.0675893125237721,-0.6762613686786177,-1.0269644237018638,-0.3128524860801805,-0.40647496893386675,-0.3705139653498329,-0.7600651400691047,-1.0114146452925903,-0.4022584316319489,-0.3637206037779236,-0.3416567713160719,-0.3233494187236225,-0.4483659703171235,-1.0479908093681 ...
